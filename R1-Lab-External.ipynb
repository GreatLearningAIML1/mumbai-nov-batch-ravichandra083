# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Iris.csv")
df
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
df.head()
df.tail()
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
df.set_index("Sepal Length (in cm)", inplace= True)
df
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
# 5.4                                   3.7                   1.5
# 4.8                                   3.4                   1.6
# 4.8                                   3.0                   1.4
# 4.3                                   3.0                   1.1
# 5.8                                   4.0                   1.2
# 5.7                                   4.4                   1.5
# 5.4                                   3.9                   1.3
# 5.1                                   3.5                   1.4
# 5.7                                   3.8                   1.7
# 5.1                                   3.8                   1.5
# 5.4                                   3.4                   1.7
# 5.1                                   3.7                   1.5
# 4.6                                   3.6                   1.0
# 5.1                                   3.3                   1.7
# 4.8                                   3.4                   1.9
# 5.0                                   3.0                   1.6
# 5.0                                   3.4                   1.6
# 5.2                                   3.5                   1.5
# 5.2                                   3.4                   1.4
# 4.7                                   3.2                   1.6
# ...                                   ...                   ...
# 6.9                                   3.2                   5.7
# 5.6                                   2.8                   4.9
# 7.7                                   2.8                   6.7
# 6.3                                   2.7                   4.9
# 6.7                                   3.3                   5.7
# 7.2                                   3.2                   6.0
# 6.2                                   2.8                   4.8
# 6.1                                   3.0                   4.9
# 6.4                                   2.8                   5.6
# 7.2                                   3.0                   5.8
# 7.4                                   2.8                   6.1
# 7.9                                   3.8                   6.4
# 6.4                                   2.8                   5.6
# 6.3                                   2.8                   5.1
# 6.1                                   2.6                   5.6
# 7.7                                   3.0                   6.1
# 6.3                                   3.4                   5.6
# 6.4                                   3.1                   5.5
# 6.0                                   3.0                   4.8
# 6.9                                   3.1                   5.4
# 6.7                                   3.1                   5.6
# 6.9                                   3.1                   5.1
# 5.8                                   2.7                   5.1
# 6.8                                   3.2                   5.9
# 6.7                                   3.3                   5.7
# 6.7                                   3.0                   5.2
# 6.3                                   2.5                   5.0
# 6.5                                   3.0                   5.2
# 6.2                                   3.4                   5.4
# 5.9                                   3.0                   5.1
#
#                       Petal width (in cm)           Class
# Sepal Length (in cm)
# 5.1                                   0.2     Iris-setosa
# 4.9                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 5.4                                   0.4     Iris-setosa
# 4.6                                   0.3     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 4.4                                   0.2     Iris-setosa
# 4.9                                   0.1     Iris-setosa
# 5.4                                   0.2     Iris-setosa
# 4.8                                   0.2     Iris-setosa
# 4.8                                   0.1     Iris-setosa
# 4.3                                   0.1     Iris-setosa
# 5.8                                   0.2     Iris-setosa
# 5.7                                   0.4     Iris-setosa
# 5.4                                   0.4     Iris-setosa
# 5.1                                   0.3     Iris-setosa
# 5.7                                   0.3     Iris-setosa
# 5.1                                   0.3     Iris-setosa
# 5.4                                   0.2     Iris-setosa
# 5.1                                   0.4     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.1                                   0.5     Iris-setosa
# 4.8                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 5.0                                   0.4     Iris-setosa
# 5.2                                   0.2     Iris-setosa
# 5.2                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# ...                                   ...             ...
# 6.9                                   2.3  Iris-virginica
# 5.6                                   2.0  Iris-virginica
# 7.7                                   2.0  Iris-virginica
# 6.3                                   1.8  Iris-virginica
# 6.7                                   2.1  Iris-virginica
# 7.2                                   1.8  Iris-virginica
# 6.2                                   1.8  Iris-virginica
# 6.1                                   1.8  Iris-virginica
# 6.4                                   2.1  Iris-virginica
# 7.2                                   1.6  Iris-virginica
# 7.4                                   1.9  Iris-virginica
# 7.9                                   2.0  Iris-virginica
# 6.4                                   2.2  Iris-virginica
# 6.3                                   1.5  Iris-virginica
# 6.1                                   1.4  Iris-virginica
# 7.7                                   2.3  Iris-virginica
# 6.3                                   2.4  Iris-virginica
# 6.4                                   1.8  Iris-virginica
# 6.0                                   1.8  Iris-virginica
# 6.9                                   2.1  Iris-virginica
# 6.7                                   2.4  Iris-virginica
# 6.9                                   2.3  Iris-virginica
# 5.8                                   1.9  Iris-virginica
# 6.8                                   2.3  Iris-virginica
# 6.7                                   2.5  Iris-virginica
# 6.7                                   2.3  Iris-virginica
# 6.3                                   1.9  Iris-virginica
# 6.5                                   2.0  Iris-virginica
# 6.2                                   2.3  Iris-virginica
# 5.9                                   1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 150 entries, 5.1 to 5.9
# Data columns (total 4 columns):
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(3), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
df.iloc[:,[2]]
# Out:
#                       Petal width (in cm)
# Sepal Length (in cm)
# 5.1                                   0.2
# 4.9                                   0.2
# 4.7                                   0.2
# 4.6                                   0.2
# 5.0                                   0.2
# 5.4                                   0.4
# 4.6                                   0.3
# 5.0                                   0.2
# 4.4                                   0.2
# 4.9                                   0.1
# 5.4                                   0.2
# 4.8                                   0.2
# 4.8                                   0.1
# 4.3                                   0.1
# 5.8                                   0.2
# 5.7                                   0.4
# 5.4                                   0.4
# 5.1                                   0.3
# 5.7                                   0.3
# 5.1                                   0.3
# 5.4                                   0.2
# 5.1                                   0.4
# 4.6                                   0.2
# 5.1                                   0.5
# 4.8                                   0.2
# 5.0                                   0.2
# 5.0                                   0.4
# 5.2                                   0.2
# 5.2                                   0.2
# 4.7                                   0.2
# ...                                   ...
# 6.9                                   2.3
# 5.6                                   2.0
# 7.7                                   2.0
# 6.3                                   1.8
# 6.7                                   2.1
# 7.2                                   1.8
# 6.2                                   1.8
# 6.1                                   1.8
# 6.4                                   2.1
# 7.2                                   1.6
# 7.4                                   1.9
# 7.9                                   2.0
# 6.4                                   2.2
# 6.3                                   1.5
# 6.1                                   1.4
# 7.7                                   2.3
# 6.3                                   2.4
# 6.4                                   1.8
# 6.0                                   1.8
# 6.9                                   2.1
# 6.7                                   2.4
# 6.9                                   2.3
# 5.8                                   1.9
# 6.8                                   2.3
# 6.7                                   2.5
# 6.7                                   2.3
# 6.3                                   1.9
# 6.5                                   2.0
# 6.2                                   2.3
# 5.9                                   1.8
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
df.iloc[0:10,0:1]
# Out:
#                       Sepal Width in (cm)
# Sepal Length (in cm)
# 5.1                                   3.5
# 4.9                                   3.0
# 4.7                                   3.2
# 4.6                                   3.1
# 5.0                                   3.6
# 5.4                                   3.9
# 4.6                                   3.4
# 5.0                                   3.4
# 4.4                                   2.9
# 4.9                                   3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
df[df.Class=="Iris-setosa"]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 31                   5.4                  3.4                   1.5
# 32                   5.2                  4.1                   1.5
# 33                   5.5                  4.2                   1.4
# 34                   4.9                  3.1                   1.5
# 35                   5.0                  3.2                   1.2
# 36                   5.5                  3.5                   1.3
# 37                   4.9                  3.1                   1.5
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 40                   5.0                  3.5                   1.3
# 41                   4.5                  2.3                   1.3
# 42                   4.4                  3.2                   1.3
# 43                   5.0                  3.5                   1.6
# 44                   5.1                  3.8                   1.9
# 45                   4.8                  3.0                   1.4
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class  SepalExtra
# 0                   0.2  Iris-setosa       17.85
# 1                   0.2  Iris-setosa       14.70
# 2                   0.2  Iris-setosa       15.04
# 3                   0.2  Iris-setosa       14.26
# 4                   0.2  Iris-setosa       18.00
# 5                   0.4  Iris-setosa       21.06
# 6                   0.3  Iris-setosa       15.64
# 7                   0.2  Iris-setosa       17.00
# 8                   0.2  Iris-setosa       12.76
# 9                   0.1  Iris-setosa       15.19
# 10                  0.2  Iris-setosa       19.98
# 11                  0.2  Iris-setosa       16.32
# 12                  0.1  Iris-setosa       14.40
# 13                  0.1  Iris-setosa       12.90
# 14                  0.2  Iris-setosa       23.20
# 15                  0.4  Iris-setosa       25.08
# 16                  0.4  Iris-setosa       21.06
# 17                  0.3  Iris-setosa       17.85
# 18                  0.3  Iris-setosa       21.66
# 19                  0.3  Iris-setosa       19.38
# 20                  0.2  Iris-setosa       18.36
# 21                  0.4  Iris-setosa       18.87
# 22                  0.2  Iris-setosa       16.56
# 23                  0.5  Iris-setosa       16.83
# 24                  0.2  Iris-setosa       16.32
# 25                  0.2  Iris-setosa       15.00
# 26                  0.4  Iris-setosa       17.00
# 27                  0.2  Iris-setosa       18.20
# 28                  0.2  Iris-setosa       17.68
# 29                  0.2  Iris-setosa       15.04
# 30                  0.2  Iris-setosa       14.88
# 31                  0.4  Iris-setosa       18.36
# 32                  0.1  Iris-setosa       21.32
# 33                  0.2  Iris-setosa       23.10
# 34                  0.1  Iris-setosa       15.19
# 35                  0.2  Iris-setosa       16.00
# 36                  0.2  Iris-setosa       19.25
# 37                  0.1  Iris-setosa       15.19
# 38                  0.2  Iris-setosa       13.20
# 39                  0.2  Iris-setosa       17.34
# 40                  0.3  Iris-setosa       17.50
# 41                  0.3  Iris-setosa       10.35
# 42                  0.2  Iris-setosa       14.08
# 43                  0.6  Iris-setosa       17.50
# 44                  0.4  Iris-setosa       19.38
# 45                  0.3  Iris-setosa       14.40
# 46                  0.2  Iris-setosa       19.38
# 47                  0.2  Iris-setosa       14.72
# 48                  0.2  Iris-setosa       19.61
# 49                  0.2  Iris-setosa       16.50

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
df = pd.read_csv("Iris.csv")
df["SepalExtra"] = df["Sepal Length (in cm)"]*df["Sepal Width in (cm)"]
df
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class  SepalExtra
# 0                    0.2     Iris-setosa       17.85
# 1                    0.2     Iris-setosa       14.70
# 2                    0.2     Iris-setosa       15.04
# 3                    0.2     Iris-setosa       14.26
# 4                    0.2     Iris-setosa       18.00
# 5                    0.4     Iris-setosa       21.06
# 6                    0.3     Iris-setosa       15.64
# 7                    0.2     Iris-setosa       17.00
# 8                    0.2     Iris-setosa       12.76
# 9                    0.1     Iris-setosa       15.19
# 10                   0.2     Iris-setosa       19.98
# 11                   0.2     Iris-setosa       16.32
# 12                   0.1     Iris-setosa       14.40
# 13                   0.1     Iris-setosa       12.90
# 14                   0.2     Iris-setosa       23.20
# 15                   0.4     Iris-setosa       25.08
# 16                   0.4     Iris-setosa       21.06
# 17                   0.3     Iris-setosa       17.85
# 18                   0.3     Iris-setosa       21.66
# 19                   0.3     Iris-setosa       19.38
# 20                   0.2     Iris-setosa       18.36
# 21                   0.4     Iris-setosa       18.87
# 22                   0.2     Iris-setosa       16.56
# 23                   0.5     Iris-setosa       16.83
# 24                   0.2     Iris-setosa       16.32
# 25                   0.2     Iris-setosa       15.00
# 26                   0.4     Iris-setosa       17.00
# 27                   0.2     Iris-setosa       18.20
# 28                   0.2     Iris-setosa       17.68
# 29                   0.2     Iris-setosa       15.04
# ..                   ...             ...         ...
# 120                  2.3  Iris-virginica       22.08
# 121                  2.0  Iris-virginica       15.68
# 122                  2.0  Iris-virginica       21.56
# 123                  1.8  Iris-virginica       17.01
# 124                  2.1  Iris-virginica       22.11
# 125                  1.8  Iris-virginica       23.04
# 126                  1.8  Iris-virginica       17.36
# 127                  1.8  Iris-virginica       18.30
# 128                  2.1  Iris-virginica       17.92
# 129                  1.6  Iris-virginica       21.60
# 130                  1.9  Iris-virginica       20.72
# 131                  2.0  Iris-virginica       30.02
# 132                  2.2  Iris-virginica       17.92
# 133                  1.5  Iris-virginica       17.64
# 134                  1.4  Iris-virginica       15.86
# 135                  2.3  Iris-virginica       23.10
# 136                  2.4  Iris-virginica       21.42
# 137                  1.8  Iris-virginica       19.84
# 138                  1.8  Iris-virginica       18.00
# 139                  2.1  Iris-virginica       21.39
# 140                  2.4  Iris-virginica       20.77
# 141                  2.3  Iris-virginica       21.39
# 142                  1.9  Iris-virginica       15.66
# 143                  2.3  Iris-virginica       21.76
# 144                  2.5  Iris-virginica       22.11
# 145                  2.3  Iris-virginica       20.10
# 146                  1.9  Iris-virginica       15.75
# 147                  2.0  Iris-virginica       19.50
# 148                  2.3  Iris-virginica       21.08
# 149                  1.8  Iris-virginica       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
df[df.Class=="Iris-setosa"].mean()
df[df.Class=="Iris-setosa"].var()
df[df.Class=="Iris-versicolor"].mean()
df[df.Class=="Iris-versicolor"].var()
df[df.Class=="Iris-virginica"].mean()
df[df.Class=="Iris-virginica"].var()
# Out:
# Sepal Length (in cm)     0.404343
# Sepal Width in (cm)      0.104004
# Petal length (in cm)     0.304588
# Petal width (in cm)      0.075433
# SepalExtra              11.963180
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
summary=df.describe()
summary_max=summary.loc["max",:]
summary_min=summary.loc["min",:]
Range=summary_max-summary_min
Range
# Out:
# Sepal Length (in cm)     3.60
# Sepal Width in (cm)      2.40
# Petal length (in cm)     5.90
# Petal width (in cm)      2.40
# SepalExtra              20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
df.sort_values(by=['Petal width (in cm)'],ascending=True,inplace=False)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 34                    4.9                  3.1                   1.5
# 0                     5.1                  3.5                   1.4
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# 30                    4.8                  3.1                   1.6
# 33                    5.5                  4.2                   1.4
# 36                    5.5                  3.5                   1.3
# 38                    4.4                  3.0                   1.3
# 39                    5.1                  3.4                   1.5
# 42                    4.4                  3.2                   1.3
# 46                    5.1                  3.8                   1.6
# 47                    4.6                  3.2                   1.4
# 48                    5.3                  3.7                   1.5
# 49                    5.0                  3.3                   1.4
# 25                    5.0                  3.0                   1.6
# 24                    4.8                  3.4                   1.9
# 35                    5.0                  3.2                   1.2
# 3                     4.6                  3.1                   1.5
# 2                     4.7                  3.2                   1.3
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 10                    5.4                  3.7                   1.5
# 4                     5.0                  3.6                   1.4
# 11                    4.8                  3.4                   1.6
# ..                    ...                  ...                   ...
# 111                   6.4                  2.7                   5.3
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 147                   6.5                  3.0                   5.2
# 113                   5.7                  2.5                   5.0
# 131                   7.9                  3.8                   6.4
# 110                   6.5                  3.2                   5.1
# 139                   6.9                  3.1                   5.4
# 102                   7.1                  3.0                   5.9
# 112                   6.8                  3.0                   5.5
# 105                   7.6                  3.0                   6.6
# 124                   6.7                  3.3                   5.7
# 128                   6.4                  2.8                   5.6
# 117                   7.7                  3.8                   6.7
# 132                   6.4                  2.8                   5.6
# 104                   6.5                  3.0                   5.8
# 120                   6.9                  3.2                   5.7
# 115                   6.4                  3.2                   5.3
# 148                   6.2                  3.4                   5.4
# 141                   6.9                  3.1                   5.1
# 143                   6.8                  3.2                   5.9
# 145                   6.7                  3.0                   5.2
# 118                   7.7                  2.6                   6.9
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 140                   6.7                  3.1                   5.6
# 114                   5.8                  2.8                   5.1
# 100                   6.3                  3.3                   6.0
# 144                   6.7                  3.3                   5.7
# 109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class  SepalExtra
# 32                   0.1     Iris-setosa       21.32
# 13                   0.1     Iris-setosa       12.90
# 37                   0.1     Iris-setosa       15.19
# 9                    0.1     Iris-setosa       15.19
# 12                   0.1     Iris-setosa       14.40
# 34                   0.1     Iris-setosa       15.19
# 0                    0.2     Iris-setosa       17.85
# 27                   0.2     Iris-setosa       18.20
# 28                   0.2     Iris-setosa       17.68
# 29                   0.2     Iris-setosa       15.04
# 30                   0.2     Iris-setosa       14.88
# 33                   0.2     Iris-setosa       23.10
# 36                   0.2     Iris-setosa       19.25
# 38                   0.2     Iris-setosa       13.20
# 39                   0.2     Iris-setosa       17.34
# 42                   0.2     Iris-setosa       14.08
# 46                   0.2     Iris-setosa       19.38
# 47                   0.2     Iris-setosa       14.72
# 48                   0.2     Iris-setosa       19.61
# 49                   0.2     Iris-setosa       16.50
# 25                   0.2     Iris-setosa       15.00
# 24                   0.2     Iris-setosa       16.32
# 35                   0.2     Iris-setosa       16.00
# 3                    0.2     Iris-setosa       14.26
# 2                    0.2     Iris-setosa       15.04
# 7                    0.2     Iris-setosa       17.00
# 8                    0.2     Iris-setosa       12.76
# 10                   0.2     Iris-setosa       19.98
# 4                    0.2     Iris-setosa       18.00
# 11                   0.2     Iris-setosa       16.32
# ..                   ...             ...         ...
# 111                  1.9  Iris-virginica       17.28
# 121                  2.0  Iris-virginica       15.68
# 122                  2.0  Iris-virginica       21.56
# 147                  2.0  Iris-virginica       19.50
# 113                  2.0  Iris-virginica       14.25
# 131                  2.0  Iris-virginica       30.02
# 110                  2.0  Iris-virginica       20.80
# 139                  2.1  Iris-virginica       21.39
# 102                  2.1  Iris-virginica       21.30
# 112                  2.1  Iris-virginica       20.40
# 105                  2.1  Iris-virginica       22.80
# 124                  2.1  Iris-virginica       22.11
# 128                  2.1  Iris-virginica       17.92
# 117                  2.2  Iris-virginica       29.26
# 132                  2.2  Iris-virginica       17.92
# 104                  2.2  Iris-virginica       19.50
# 120                  2.3  Iris-virginica       22.08
# 115                  2.3  Iris-virginica       20.48
# 148                  2.3  Iris-virginica       21.08
# 141                  2.3  Iris-virginica       21.39
# 143                  2.3  Iris-virginica       21.76
# 145                  2.3  Iris-virginica       20.10
# 118                  2.3  Iris-virginica       20.02
# 135                  2.3  Iris-virginica       23.10
# 136                  2.4  Iris-virginica       21.42
# 140                  2.4  Iris-virginica       20.77
# 114                  2.4  Iris-virginica       16.24
# 100                  2.5  Iris-virginica       20.79
# 144                  2.5  Iris-virginica       22.11
# 109                  2.5  Iris-virginica       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
df.drop("SepalExtra",axis=1)

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=df.iloc[0:10,0:3]
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import pandas pd
import numpy as np

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
data_set= pd.read_csv("HR.txt",delimiter="\t")
data_set.head(3)
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                 1          2               1              1
# 1                 8          1               1              1
# 2                 2          2               6              1
#
#            ...           RelationshipSatisfaction  StandardHours  \
# 0          ...                                  1             80
# 1          ...                                  4             80
# 2          ...                                  2             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
#
# [3 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
data_set.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Individual                  1470 non-null object
# Attrition                   1470 non-null object
# Age                         1470 non-null int64
# BusinessTravel              1470 non-null int64
# DailyRate                   1470 non-null int64
# Department                  1470 non-null int64
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null int64
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null int64
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null int64
# JobSatisfaction             1470 non-null int64
# MaritalStatus               1470 non-null int64
# MonthlyIncome               1470 non-null int64
# MonthlyRate                 1470 non-null int64
# NumCompaniesWorked          1470 non-null int64
# OverTime                    1470 non-null int64
# PercentSalaryHike           1470 non-null int64
# PerformanceRating           1470 non-null int64
# RelationshipSatisfaction    1470 non-null int64
# StandardHours               1470 non-null int64
# StockOptionLevel            1470 non-null int64
# TotalWorkingYears           1470 non-null int64
# TrainingTimesLastYear       1470 non-null int64
# WorkLifeBalance             1470 non-null int64
# YearsAtCompany              1470 non-null int64
# YearsInCurrentRole          1470 non-null int64
# YearsSinceLastPromotion     1470 non-null int64
# YearsWithCurrManager        1470 non-null int64
# dtypes: int64(33), object(2)
# memory usage: 402.0+ KB

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
data_set.iloc[:,3:10]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
data_set[data_set.Gender== 1].count() ## 882 males found
#total no of rows =1470, hence no of females 1470-882= 588
# sum males and females is equal to 1470
data_set["Gender"].count()
# Out:
# 1470

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
iqr=data_set["Age"].quantile(0.75)-data_set["Age"].quantile(0.25)
iqr
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
data_set["DailyRate"].mean()
data_set["DailyRate"].median()
data_set["DailyRate"].var()
# Out:
# 802.0

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
df12=data_set["Attrition"]
y_pos = np.arange(len(df12))
plt.hist(df12,y_pos,rwidth=0.95)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-296-d2ca07544986> in <module>()
#       4 df12=data_set["Attrition"]
#       5 y_pos = np.arange(len(df12))
# ----> 6 plt.hist(df12,y_pos,rwidth=0.95)
#       7 plt.show()
#
# C:\Users\Ravichandra\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    3079                       histtype=histtype, align=align, orientation=orientation,
#    3080                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3081                       stacked=stacked, data=data, **kwargs)
#    3082     finally:
#    3083         ax._hold = washold
#
# C:\Users\Ravichandra\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Users\Ravichandra\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6193             # this will automatically overwrite bins,
#    6194             # so that each histogram uses the same bins
# -> 6195             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6196             m = m.astype(float)  # causes problems later if it's an int
#    6197             if mlast is None:
#
# C:\Users\Ravichandra\Anaconda3\lib\site-packages\numpy\lib\function_base.py in histogram(a, bins, range, normed, weights, density)
#     659             mn, mx = 0.0, 1.0
#     660         else:
# --> 661             mn, mx = a.min() + 0.0, a.max() + 0.0
#     662     else:
#     663         mn, mx = [mi + 0.0 for mi in range]
#
# C:\Users\Ravichandra\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: cannot perform reduce with flexible type

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-288-ebb5da34fa23> in <module>()
#       1 height = [0,1,50,100,250,]
#       2 y_pos = np.arange(len(p))
# ----> 3 plt.bar(y_pos, height)
#       4 plt.xticks(y_pos,height)
#       5 plt.show()
#
# C:\Users\Ravichandra\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# C:\Users\Ravichandra\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Users\Ravichandra\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2077         if len(height) != nbars:
#    2078             raise ValueError("incompatible sizes: argument 'height' "
# -> 2079                               "must be length %d or scalar" % nbars)
#    2080         if len(width) != nbars:
#    2081             raise ValueError("incompatible sizes: argument 'width' "
#
# ValueError: incompatible sizes: argument 'height' must be length 1470 or scalar

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
df15=data_set["TotalWorkingYears"]
import numpy as np
import matplotlib.pyplot as plt
plt.hist(df15,rwidth=0.95)
plt.show()
