# %%
import pandas as pd
import numpy as np
from sklearn import tree, model_selection

# %%
HPR_TRAIN = pd.read_csv("High_product_risk.csv")
HPR_TEST = pd.read_csv("HPR_test.csv")

# %%
HPR_TRAIN.drop('Unnamed: 0', axis=1,inplace = True)

# %%
HPR.head(5)
# Out:
#    TOTAL_REVIEWER_EXPERIENCE  TOTAL_ANALYST_EXPERIENCE  \
# 0                          3                       465
# 1                        161                       197
# 2                         16                       147
# 3                        438                        22
# 4                        954                       457
#
#    product_test_classification  invalid_oos_oot  \
# 0                            3                0
# 1                            3                0
# 2                            3                0
# 3                            3                0
# 4                            3                0
#
#    ANALYST_PRODUCT_TEST_EXPERIENCE  ANALYST_TEST_EXPERIENCE  \
# 0                              1.0                     20.0
# 1                              3.0                     71.0
# 2                              NaN                      NaN
# 3                              1.0                      6.0
# ...

# %%
HPR_TEST.drop('Unnamed: 0', axis=1,inplace = True)

# %%
HPR_TEST.head(5)
# Out:
#    TOTAL_REVIEWER_EXPERIENCE  TOTAL_ANALYST_EXPERIENCE  \
# 0                        281                       317
# 1                        336                        45
# 2                        103                        21
# 3                        173                       419
# 4                        274                        40
#
#    product_test_classification  invalid_oos_oot  \
# 0                            3                0
# 1                            3                0
# 2                            3                0
# 3                            3                0
# 4                            3                0
#
#    ANALYST_PRODUCT_TEST_EXPERIENCE  ANALYST_TEST_EXPERIENCE  \
# 0                             16.0                     77.0
# 1                              3.0                     20.0
# 2                              NaN                      8.0
# 3                              1.0                      4.0
# ...

# %%
features = ['TOTAL_REVIEWER_EXPERIENCE','TOTAL_ANALYST_EXPERIENCE','product_test_classification','ANALYST_PRODUCT_TEST_EXPERIENCE','ANALYST_TEST_EXPERIENCE','ANALYST_PRODUCT_EXPERIENCE','ANALYST_RATING','REVIEWER_RATING','HOLIDAY','Manager.Span','Night_shift']
X_train= HPR_TRAIN[features]
y_train= HPR_TRAIN[['invalid_oos_oot']]
#results = model_selection.cross_validate(classifier, X_train,y_train, cv =10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-11e67f12176d> in <module>()
#       2 X_train= HPR_TRAIN[features]
#       3 y_train= HPR_TRAIN[['invalid_oos_oot']]
# ----> 4 results = model_selection.cross_validate(classifier, X_train,y_train, cv =10)
#
# NameError: name 'model_selection' is not defined

# %%
X_train.head(3)
# Out:
#    TOTAL_REVIEWER_EXPERIENCE  TOTAL_ANALYST_EXPERIENCE  \
# 0                          3                       465
# 1                        161                       197
# 2                         16                       147
#
#    product_test_classification  ANALYST_PRODUCT_TEST_EXPERIENCE  \
# 0                            3                              1.0
# 1                            3                              3.0
# 2                            3                              NaN
#
#    ANALYST_TEST_EXPERIENCE  ANALYST_PRODUCT_EXPERIENCE  ANALYST_RATING  \
# 0                     20.0                         2.0             2.0
# 1                     71.0                         7.0             NaN
# 2                      NaN                         1.0             NaN
#
#    REVIEWER_RATING  HOLIDAY  Manager.Span  Night_shift
# 0              3.0        0          26.0            0
# 1              3.0        0           8.0            0
# ...

# %%
y_train.head(3)
# Out:
#    invalid_oos_oot
# 0                0
# 1                0
# 2                0

# %%
classifier = tree.DecisionTreeClassifier()
dt_grid = {'max_depth':[3,4,5,6,7,8,9,10],'criterion':['gini', 'entropy']}
grid_classifier = model_selection.GridsearchCV(classifier, dt_grid, cv=10,refit=True, return_train_score= True)
grid_classifier.fit(X_train, y_train)
results = grid_classfier.CV_results_
print(results.get('params'))
print(results.get('mean_test_score'))
print(results.get('mean_train_score'))
print(grid_classifier.best_params_)
print(grid_classifier.best_score_)
final_model = grid_classifer.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-a3337e988e8a> in <module>()
#       1 classifier = tree.DecisionTreeClassifier()
#       2 dt_grid = {'max_depth':[3,4,5,6,7,8,9,10],'criterion':['gini', 'entropy']}
# ----> 3 grid_classifier = model_selection.GridsearchCV(classifier, dt_grid, cv=10,refit=True, return_train_score= True)
#       4 grid_classifier.fit(X_train, y_train)
#       5 results = grid_classfier.CV_results_
#
# AttributeError: module 'sklearn.model_selection' has no attribute 'GridsearchCV'
